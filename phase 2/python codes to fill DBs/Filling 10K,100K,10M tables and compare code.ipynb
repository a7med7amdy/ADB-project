# %% [markdown]
# # filling the 10K,100K,10M databases

# %%
#10K database

import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="01021592414ahmed",
  database="Testing_project1"
)

mycursor=mydb.cursor()


#--------------- bank table insertion ---------------------------
query="insert into bank (Bank_code,Address,Name) values "
for i in range(1,10001):
    query+="("+str(i)+", 'cairo,street "+str(i)+"', 'bank_"+str(i)+"')"
    if i!=10000:
        query+=","
mycursor.execute(query)
mydb.commit()

#--------------- branch table insertion ---------------------------
query="insert into branch values "
for i in range(1,10001):
    query+="("+str(i)+", 'branch_"+str(i)+"', 'cairo,street "+str(i)+"',"+str(i)+")"
    if i!=10000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- Loan table insertion ---------------------------
query="insert into Loan values "
for i in range(1,10001):
    query+="("+str(i)+", "+str(i%2)+", "+str(i)+", "+str(i)+")"
    if i!=10000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- Account table insertion ---------------------------
query="insert into Account values "
for i in range(1,10001):
    query+="("+str(i)+", "+str(i%2)+", "+str(i)+", "+str(i)+")"
    if i!=10000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- customer table insertion ---------------------------
query="insert into customer values "
for i in range(1,10001):
    query+="("+str(i)+", 'Ahmed_"+str(i)+"',"+str(i)+", 'Giza,street"+str(i)+"')"
    if i!=10000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- Hold_by table insertion ---------------------------
query="insert into Hold_by values "
for i in range(1,10001):
    query+="("+str(i)+", "+str(i)+")"
    if i!=10000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- Availed_by table insertion ---------------------------
query="insert into Availed_by values "
for i in range(1,10001):
    query+="("+str(i)+", "+str(i)+")"
    if i!=10000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)
# Out:
# insert into branch values (1, 'branch_1', 'cairo,street 1',1),(2, 'branch_2', 'cairo,street 2',2),(3, 'branch_3', 'cairo,street 3',3),(4, 'branch_4', 'cairo,street 4',4),(5, 'branch_5', 'cairo,street 5',5),(6, 'branch_6', 'cairo,street 6',6),(7, 'branch_7', 'cairo,street 7',7),(8, 'branch_8', 'cairo,street 8',8),(9, 'branch_9', 'cairo,street 9',9),(10, 'branch_10', 'cairo,street 10',10),(11, 'branch_11', 'cairo,street 11',11),(12, 'branch_12', 'cairo,street 12',12),(13, 'branch_13', 'cairo,street 13',13),(14, 'branch_14', 'cairo,street 14',14),(15, 'branch_15', 'cairo,street 15',15),(16, 'branch_16', 'cairo,street 16',16),(17, 'branch_17', 'cairo,street 17',17),(18, 'branch_18', 'cairo,street 18',18),(19, 'branch_19', 'cairo,street 19',19),(20, 'branch_20', 'cairo,street 20',20),(21, 'branch_21', 'cairo,street 21',21),(22, 'branch_22', 'cairo,street 22',22),(23, 'branch_23', 'cairo,street 23',23),(24, 'branch_24', 'cairo,street 24',24),(25, 'branch_25', 'cairo,street 25',25),(26, 'branch_26', 'cairo,street 26',26),(27, 'branch_27', 'cairo,street 27',27),(28, 'branch_28', 'cairo,street 28',28),(29, 'branch_29', 'cairo,street 29',29),(30, 'branch_30', 'cairo,street 30',30),(31, 'branch_31', 'cairo,street 31',31),(32, 'branch_32', 'cairo,street 32',32),(33, 'branch_33', 'cairo,street 33',33),(34, 'branch_34', 'cairo,street 34',34),(35, 'branch_35', 'cairo,street 35',35),(36, 'branch_36', 'cairo,street 36',36),(37, 'branch_37', 'cairo,street 37',37),(38, 'branch_38', 'cairo,street 38',38),(39, 'branch_39', 'cairo,street 39',39),(40, 'branch_40', 'cairo,street 40',40),(41, 'branch_41', 'cairo,street 41',41),(42, 'branch_42', 'cairo,street 42',42),(43, 'branch_43', 'cairo,street 43',43),(44, 'branch_44', 'cairo,street 44',44),(45, 'branch_45', 'cairo,street 45',45),(46, 'branch_46', 'cairo,street 46',46),(47, 'branch_47', 'cairo,street 47',47),(48, 'branch_48', 'cairo,street 48',48),(49, 'branch_49', 'cairo,street 49',49),(50, 'branch_50', 'cairo,street 50',50),(51, 'branch_51', 'cairo,street 51',51),(52, 'branch_52', 'cairo,street 52',52),(53, 'branch_53', 'cairo,street 53',53),(54, 'branch_54', 'cairo,street 54',54),(55, 'branch_55', 'cairo,street 55',55),(56, 'branch_56', 'cairo,street 56',56),(57, 'branch_57', 'cairo,street 57',57),(58, 'branch_58', 'cairo,street 58',58),(59, 'branch_59', 'cairo,street 59',59),(60, 'branch_60', 'cairo,street 60',60),(61, 'branch_61', 'cairo,street 61',61),(62, 'branch_62', 'cairo,street 62',62),(63, 'branch_63', 'cairo,street 63',63),(64, 'branch_64', 'cairo,street 64',64),(65, 'branch_65', 'cairo,street 65',65),(66, 'branch_66', 'cairo,street 66',66),(67, 'branch_67', 'cairo,street 67',67),(68, 'branch_68', 'cairo,street 68',68),(69, 'branch_69', 'cairo,street 69',69),(70, 'branch_70', 'cairo,street 70',70),(71, 'branch_71', 'cairo,street 71',71),(72, 'branch_72', 'cairo,street 72',72),(73, 'branch_73', 'cairo,street 73',73),(74, 'branch_74', 'cairo,street 74',74),(75, 'branch_75', 'cairo,street 75',75),(76, 'branch_76', 'cairo,street 76',76),(77, 'branch_77', 'cairo,street 77',77),(78, 'branch_78', 'cairo,street 78',78),(79, 'branch_79', 'cairo,street 79',79),(80, 'branch_80', 'cairo,street 80',80),(81, 'branch_81', 'cairo,street 81',81),(82, 'branch_82', 'cairo,street 82',82),(83, 'branch_83', 'cairo,street 83',83),(84, 'branch_84', 'cairo,street 84',84),(85, 'branch_85', 'cairo,street 85',85),(86, 'branch_86', 'cairo,street 86',86),(87, 'branch_87', 'cairo,street 87',87),(88, 'branch_88', 'cairo,street 88',88),(89, 'branch_89', 'cairo,street 89',89),(90, 'branch_90', 'cairo,street 90',90),(91, 'branch_91', 'cairo,street 91',91),(92, 'branch_92', 'cairo,street 92',92),(93, 'branch_93', 'cairo,street 93',93),(94, 'branch_94', 'cairo,street 94',94),(95, 'branch_95', 'cairo,street 95',95),(96, 'branch_96', 'cairo,street 96',96),(97, 'branch_97', 'cairo,street 97',97),(98, 'branch_98', 'cairo,street 98',98),(99, 'branch_99', 'cairo,street 99',99),(100, 'branch_100', 'cairo,street 100',100),(101,  ...

# %%
#100K database
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="01021592414ahmed",
  database="Testing_project2"
)

mycursor=mydb.cursor()


#--------------- bank table insertion ---------------------------
query="insert into bank (Bank_code,Address,Name) values "
for i in range(1,100001):
    query+="("+str(i)+", 'cairo,street "+str(i)+"', 'bank_"+str(i)+"')"
    if i!=100000:
        query+=","
mycursor.execute(query)
mydb.commit()

#--------------- branch table insertion ---------------------------
query="insert into branch values "
for i in range(1,100001):
    query+="("+str(i)+", 'branch_"+str(i)+"', 'cairo,street "+str(i)+"',"+str(i)+")"
    if i!=100000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- Loan table insertion ---------------------------
query="insert into Loan values "
for i in range(1,100001):
    query+="("+str(i)+", "+str(i%2)+", "+str(i)+", "+str(i)+")"
    if i!=100000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- Account table insertion ---------------------------
query="insert into Account values "
for i in range(1,100001):
    query+="("+str(i)+", "+str(i%2)+", "+str(i)+", "+str(i)+")"
    if i!=100000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- customer table insertion ---------------------------
query="insert into customer values "
for i in range(1,100001):
    query+="("+str(i)+", 'Ahmed_"+str(i)+"',"+str(i)+", 'Giza,street"+str(i)+"')"
    if i!=100000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- Hold_by table insertion ---------------------------
query="insert into Hold_by values "
for i in range(1,100001):
    query+="("+str(i)+", "+str(i)+")"
    if i!=100000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

#--------------- Availed_by table insertion ---------------------------
query="insert into Availed_by values "
for i in range(1,100001):
    query+="("+str(i)+", "+str(i)+")"
    if i!=100000:
        query+=","
mycursor.execute(query)
mydb.commit()
#print(query)

# %%
#10M database
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="01021592414ahmed",
  database="Testing_project3"
)

mycursor=mydb.cursor()

k=0
for j in range(1,11):

    #--------------- bank table insertion ---------------------------
    query="insert into bank (Bank_code,Address,Name) values "
    for i in range(1000000*k+1,1000000*j+1):
        query+="("+str(i)+", 'cairo,street "+str(i)+"', 'bank_"+str(i)+"')"
        if i!=1000000*j:
            query+=","
    mycursor.execute(query)
    mydb.commit()

    #--------------- branch table insertion ---------------------------
    query="insert into branch values "
    for i in range(1000000*k+1,1000000*j+1):
        query+="("+str(i)+", 'branch_"+str(i)+"', 'cairo,street "+str(i)+"',"+str(i)+")"
        if i!=1000000*j:
            query+=","
    mycursor.execute(query)
    mydb.commit()

    #--------------- Loan table insertion ---------------------------
    query="insert into Loan values "
    for i in range(1000000*k+1,1000000*j+1):
        query+="("+str(i)+", "+str(i%2)+", "+str(i)+", "+str(i)+")"
        if i!=1000000*j:
            query+=","
    mycursor.execute(query)
    mydb.commit()

    #--------------- Account table insertion ---------------------------
    query="insert into Account values "
    for i in range(1000000*k+1,1000000*j+1):
        query+="("+str(i)+", "+str(i%2)+", "+str(i)+", "+str(i)+")"
        if i!=1000000*j:
            query+=","
    mycursor.execute(query)
    mydb.commit()

    #--------------- customer table insertion ---------------------------
    query="insert into customer values "
    for i in range(1000000*k+1,1000000*j+1):
        query+="("+str(i)+", 'Ahmed_"+str(i)+"',"+str(i)+", 'Giza,street"+str(i)+"')"
        if i!=1000000*j:
            query+=","
    mycursor.execute(query)
    mydb.commit()

    #--------------- Hold_by table insertion ---------------------------
    query="insert into Hold_by values "
    for i in range(1000000*k+1,1000000*j+1):
        query+="("+str(i)+", "+str(i)+")"
        if i!=1000000*j:
            query+=","
    mycursor.execute(query)
    mydb.commit()

    #--------------- Availed_by table insertion ---------------------------
    query="insert into Availed_by values "
    for i in range(1000000*k+1,1000000*j+1):
        query+="("+str(i)+", "+str(i)+")"
        if i!=1000000*j:
            query+=","
    mycursor.execute(query)
    mydb.commit()
    k+=1

# %% [markdown]
# # compare between databases by the same queries

# %%
import mysql.connector
from time import time

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="01021592414ahmed",
  database="Testing_project1"
)

print("for the 10K DB")
mycursor=mydb.cursor()
mycursor.reset()

query1='''select SQL_NO_CACHE * from bank b CROSS JOIN branch h 
CROSS join Account a where b.Bank_code=h.Bank_code and a.Bno=h.Branch_id;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query1= ",toc - tic)

mycursor.reset()

query1='''select SQL_NO_CACHE c.Name, l.Bno,l.Amount from customer c 
CROSS join Availed_by a  CROSS JOIN Loan l where a.Cust_no=c.Customer_ID and a.Loan_no=l.Loan_id;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query2= ",toc - tic)

mycursor.reset()

query1='''select SQL_NO_CACHE a.Account_No, a.Balance,c.Name,c.Phone_Number, h.Acc_No,h.Cust_no from Account a 
CROSS JOIN Hold_by h CROSS JOIN customer c where h.Cust_no=c.Customer_ID and a.Account_No=h.Acc_No;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query3= ",toc - tic)
# Out:
# for the 10K DB
# query1=  0.0021975040435791016
# query2=  0.0033681392669677734
# query3=  0.005444526672363281

# %%
import mysql.connector
from time import time

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="01021592414ahmed",
  database="Testing_project2"
)

print("for the 100K DB")
mycursor=mydb.cursor()
mycursor.reset()

query1='''select SQL_NO_CACHE * from bank b CROSS JOIN branch h 
CROSS join Account a where b.Bank_code=h.Bank_code and a.Bno=h.Branch_id;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query1= ",toc - tic)

mycursor.reset()

query1='''select SQL_NO_CACHE c.Name, l.Bno,l.Amount from customer c 
CROSS join Availed_by a  CROSS JOIN Loan l where a.Cust_no=c.Customer_ID and a.Loan_no=l.Loan_id;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query2= ",toc - tic)

mycursor.reset()

query1='''select SQL_NO_CACHE a.Account_No, a.Balance,c.Name,c.Phone_Number, h.Acc_No,h.Cust_no from Account a 
CROSS JOIN Hold_by h CROSS JOIN customer c where h.Cust_no=c.Customer_ID and a.Account_No=h.Acc_No;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query3= ",toc - tic)
# Out:
# for the 100K DB
# query1=  0.02133488655090332
# query2=  0.0043637752532958984
# query3=  0.002488851547241211

# %%
import mysql.connector
from time import time

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="01021592414ahmed",
  database="Testing_project3"
)

print("for the 10M DB")
mycursor=mydb.cursor()
mycursor.reset()

query1='''select SQL_NO_CACHE * from bank b CROSS JOIN branch h 
CROSS join Account a where b.Bank_code=h.Bank_code and a.Bno=h.Branch_id;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query1= ",toc - tic)

mycursor.reset()

query1='''select SQL_NO_CACHE c.Name, l.Bno,l.Amount from customer c 
CROSS join Availed_by a  CROSS JOIN Loan l where a.Cust_no=c.Customer_ID and a.Loan_no=l.Loan_id;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query2= ",toc - tic)

mycursor.reset()

query1='''select SQL_NO_CACHE a.Account_No, a.Balance,c.Name,c.Phone_Number, h.Acc_No,h.Cust_no from Account a 
CROSS JOIN Hold_by h CROSS JOIN customer c where h.Cust_no=c.Customer_ID and a.Account_No=h.Acc_No;'''

tic = time()
mycursor.execute(query1)
toc = time()
print ("query3= ",toc - tic)
# Out:
# for the 10M DB
# query1=  0.002610445022583008
# query2=  0.005112409591674805
# query3=  0.004411935806274414
